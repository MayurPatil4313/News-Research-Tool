# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(urls=[
    'https://economictimes.indiatimes.com/tech/information-tech/wipro-liquidates-hungarian-step-down-subsidiary/articleshow/122905001.cms',
    'https://indianexpress.com/article/technology/science/spacex-starlink-satellite-launch-falcon-9-rocket-watch-live-10150836/'
])
data =loader.load()

# %%
len(data)
# Out:
# 2

# %%
print(data[1].page_content)
# Out:
# skip to content
#
# English
#
# தமிழ்
#
# বাংলা
#
# മലയാളം
#
# ગુજરાતી
#
# हिंदी
#
# मराठी
#
# Business
#
# बिज़नेस
#
# Newsletters The Indian Express Newsletter. (Opens in new window)
#
# follow us on Facebook
#
# .(Opens in new window)
#
# follow us on Twitter
#
# .(Opens in new window)
#
# follow us on youtube
#
# .(Opens in new window)
#
# follow us on Instagram
#
# .(Opens in new window)
#
# International .(Open in new tab)
#
# ePaper .Opens in new window
#
# Today’s Paper .Opens in new window
#
# The Indian Express logo
#
# Journalism of Courage
#
# Trending
#
# IND vs ENG Live Score
#
# My Express
#
# UPSC Offer
#
# Mini Crossword
#
# Express Shorts
#
# Health & Wellness
#
# 🎙️ Podcast
#
# Advertisement
#
# SpaceX to add another 24 Starlink satellites to Earth’s orbit today: Here’s how to tune in live
#
# Following last week's successful launch, SpaceX is now launching another 24 Starlink into Earth's low orbit.
#
# By: Science Desk New Delhi | Updated: July 26, 2025 13:11 IST
# ...

# %%
print(data[0].metadata)
print(data[1].metadata)
# Out:
# {'source': 'https://economictimes.indiatimes.com/tech/information-tech/wipro-liquidates-hungarian-step-down-subsidiary/articleshow/122905001.cms'}
# {'source': 'https://indianexpress.com/article/technology/science/spacex-starlink-satellite-launch-falcon-9-rocket-watch-live-10150836/'}
